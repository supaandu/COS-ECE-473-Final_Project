# %%
import requests
import pandas as pd

BASE_URL = "https://gamma-api.polymarket.com/markets"
params = {
    "limit": 100000,
    "active": "true"
}

response = requests.get(BASE_URL, params=params)
data = response.json()
markets = data

# Filter ETH markets only
eth_markets = []
keywords = ["eth", "ethereum", "eth", "Ethereum"]

for m in markets:
    question = m.get("question", "").lower()
    if any(k in question for k in keywords):
        eth_markets.append({
            "id": m.get("id"),
            "question": m.get("question"),
            "slug": m.get("slug"),
            "start_date": m.get("start_date"),
            "end_date": m.get("end_date"),
            "volume": m.get("volume_num"),
            "liquidity": m.get("liquidity_num"),
            "active": m.get("active"),
            "closed": m.get("closed")
        })

# Save filtered ETH markets
df = pd.DataFrame(eth_markets)
df.to_csv("eth_betting_markets.csv", index=False)
print(f"✅ Saved {len(df)} ETH markets.")
df.head()
# Out:
# ✅ Saved 14 ETH markets.
#       id                                           question  \
# 0     75  Will the Ethereum 2.0 Genesis Event happen suc...
# 1   8938          Will ETH be above $1,500 on January 27th?
# 2  61328     Will ETH be above $1500 on February 3rd, 2021?
# 3  71914        Will ETH be above $2000 on March 1st, 2021?
# 4  79704  Will the average Ethereum gas price be below 1...
#
#                                                 slug start_date end_date  \
# 0  will-the-ethereum-20-genesis-event-happen-succ...       None     None
# 1            will-eth-be-above-1-500-on-january-27th       None     None
# 2        will-eth-be-above-1500-on-february-3rd-2021       None     None
# 3           will-eth-be-above-2000-on-march-1st-2021       None     None
# 4  will-the-average-ethereum-gas-price-be-below-1...       None     None
#
#   volume liquidity  active  closed
# 0   None      None    True    True
# 1   None      None    True    True
# 2   None      None    True    True
# 3   None      None    True    True
# 4   None      None    True    True

# %%
def get_market_outcomes(market_id):
    url = f"https://gamma-api.polymarket.com/markets/{market_id}"
    r = requests.get(url)
    if r.status_code != 200:
        return None
    market = r.json()
    outcomes = market.get("outcomes", [])
    return outcomes

# Example: get outcome prices for one market
outcomes = get_market_outcomes("501011")  # replace with real ETH market ID
print(outcomes)

# %%
# Save to CSV
df.to_csv("polymarket_crypto_markets.csv", index=False)
